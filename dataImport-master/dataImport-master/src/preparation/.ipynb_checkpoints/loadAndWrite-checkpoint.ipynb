# %%
import requests #Used to service API connection
from lxml import html #Used to parse XML
from bs4 import BeautifulSoup #Used to read XML table on webpage
import pandas as pd
from common import cFunction as cf
import numpy as np
import wget

import psycopg2
import pandas as pd
from sqlalchemy import create_engine



# get dataList from filesystem to load and write
#dataList = pd.read_excel("../../data/inbound/dataList.xlsx")

# get dataList from spreadsheet to load and write
dataList = pd.read_csv("https://docs.google.com/spreadsheets/d/1VngqG-m7G8k1587c21MZoheR1Fz3amp1mJtiBvA1Jb0/export?format=csv&gid=0")
print("### The total number of target data is " + str(len(dataList)))

# Filtering -> get dataList only defined url
dataList = dataList[   dataList['사이트'].notnull() ]
print(dataList[["사이트"]])
print("### The total number of filtered data is " + str(len(dataList)))

###################################################
# Filtering -> for your own object
dataList = dataList[   dataList['작업자'] == "김동준" ]
###################################################

# create folder to save result
outPath = "../../data/outbound/"
folderList = dataList["폴더명"].tolist()
for i in folderList:
    cf.createFolder(outPath+i)

dataList = dataList.fillna("")
dataList = dataList.reset_index(drop=True)

# get dataList to load and write
for dataCount in range(0,len(dataList)):

    inputUrl = dataList.loc[dataCount, "사이트"]
    inputKey = dataList.loc[dataCount, "서비스키"]
    inputParameter = dataList.loc[dataCount, "파라미터"]
    inputFolder = dataList.loc[dataCount, "폴더명"]
    inputFile = dataList.loc[dataCount, "서비스명"]
    inputDataType = dataList.loc[dataCount, "데이터타입"]
    inputRefUrl = dataList.loc[dataCount, "참고문서"]
    inputRefType = dataList.loc[dataCount, "참고문서타입"]
    print(inputUrl)

    url = cf.makeURL(inputUrl,inputKey,inputParameter)
    print("fullUrl is " + url)

    newDF = pd.DataFrame()
    if (inputDataType == "xml"):
        newDF = cf.atypical_xml_process(url)
    elif(inputDataType == "json"):
        newDF = cf.jsonProcess(url)
    elif(inputDataType == "csv"):
        newDF = cf.csvProcess(url)

    fullOutPath = outPath+inputFolder+"/"+inputFolder+inputFile+".csv"
    print(fullOutPath)

    try:
        newDF.to_csv(fullOutPath, index=False, encoding="ms949")
    except Exception as x:
        print(x)

    fullOutRefPath = outPath + inputFolder + "/" + inputFolder + inputFile + "."+inputRefType
    try:
        wget.download(inputRefUrl, fullOutRefPath)
    except Exception as e:
        print(inputFolder+"참고문서 Error")
        print(e)
        pass
# Out:
# ### The total number of target data is 425
#                                                    사이트
# 305  https://www.data.go.kr/dataset/fileDownload.do...
# 306  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 307  http://apis.data.go.kr/1611000/nsdi/LandCharac...
# 308  http://apis.data.go.kr/1611000/nsdi/LandCharac...
# 309  http://apis.data.go.kr/1611000/nsdi/BuildingAg...
# 310  http://apis.data.go.kr/1611000/nsdi/BuildingAg...
# 311  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 312  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 313  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 314  http://apis.data.go.kr/1611000/nsdi/BuildingUs...
# 315  http://apis.data.go.kr/1611000/nsdi/BuildingUs...
# 316  http://apis.data.go.kr/1611000/nsdi/Fluctuatio...
# 321         https://data.myhome.go.kr/rentalHouseList?
# 326  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 327  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 348      http://apis.data.go.kr/1611000/ArchPmsService
# 350        http://fsc.go.kr/downManager?bbsid=BBS0069&
# 353  http://apis.data.go.kr/1611000/ArchPmsService/...
# 357  http://data.insight.go.kr/openapi/service/Pric...
# 360  http://openapi.molit.go.kr/OpenAPI_ToolInstall...
# 361  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 362  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 363  https://www.data.go.kr/dataset/fileDownload.do...
# 367  http://openapi.kab.co.kr/OpenAPI_ToolInstallPa...
# 368  http://api.hf.go.kr:8090/service/rest/HfMbsInt...
# 369  http://api.hf.go.kr:8090/service/rest/HfMbbInt...
# 371  https://www.data.go.kr/dataset/fileDownload.do...
# 384  https://www.data.go.kr/dataset/fileDownload.do...
# 385  http://api.hf.go.kr:8090/service/rest/uloanrat...
# 386  https://www.data.go.kr/dataset/fileDownload.do...
# 387  http://api.hf.go.kr:8090/service/rest/conforml...
# ### The total number of filtered data is 31
# http://apis.data.go.kr/1611000/nsdi/LandCharacteristicsService/wfs/getLandCharacteristicsWFS?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/LandCharacteristicsService/wfs/getLandCharacteristicsWFS?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-1토지특성정보서비스_2토지특성WFS조회 오퍼레이션 명세/308_공간융합정보-1토지특성정보서비스_2토지특성WFS조회 오퍼레이션 명세.csv
# 308_공간융합정보-1토지특성정보서비스_2토지특성WFS조회 오퍼레이션 명세참고문서 Error
# unknown url type: '%20https%3A//www.data.go.kr/commonUser/fileDownload.do?atchFileId=FILE_000000001408714&fileDetailSn=0'
# http://apis.data.go.kr/1611000/nsdi/LandCharacteristicsService/attr/getLandCharacteristics?pnu=1111010100100010000&ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/LandCharacteristicsService/attr/getLandCharacteristics?pnu=1111010100100010000&ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-1토지특성정보서비스_3토지특성속성조회 오퍼레이션 명세/308_공간융합정보-1토지특성정보서비스_3토지특성속성조회 오퍼레이션 명세.csv
# 308_공간융합정보-1토지특성정보서비스_3토지특성속성조회 오퍼레이션 명세참고문서 Error
# unknown url type: '%20https%3A//www.data.go.kr/commonUser/fileDownload.do?atchFileId=FILE_000000001408714&fileDetailSn=1'
# http://apis.data.go.kr/1611000/nsdi/BuildingAgeService/wfs/getBuildingAgeWFS?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/BuildingAgeService/wfs/getBuildingAgeWFS?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-2건축물연령정보서비스_2건축물연령WFS조회 오퍼레이션 명세/308_공간융합정보-2건축물연령정보서비스_2건축물연령WFS조회 오퍼레이션 명세.csv
# 100% [......................................................] 1496843 / 1496843http://apis.data.go.kr/1611000/nsdi/BuildingAgeService/attr/getBuildingAge?pnu=1111012500100190000&ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/BuildingAgeService/attr/getBuildingAge?pnu=1111012500100190000&ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-2건축물연령정보서비스_3건축물연령속성조회 오퍼레이션 명세/308_공간융합정보-2건축물연령정보서비스_3건축물연령속성조회 오퍼레이션 명세.csv
# 308_공간융합정보-2건축물연령정보서비스_3건축물연령속성조회 오퍼레이션 명세참고문서 Error
# HTTP Error 420: 420
# http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getByRegion?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getByRegion?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-3지가변동률정보서비스_2지역별지가변동률속성조회 오퍼레이션 명세/308_공간융합정보-3지가변동률정보서비스_2지역별지가변동률속성조회 오퍼레이션 명세.csv
# 100% [......................................................] 1496843 / 1496843http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getLargeCLByRegion?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getLargeCLByRegion?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-3지가변동률정보서비스_3권역별 지가변동률속성조회 오퍼레이션 명세/308_공간융합정보-3지가변동률정보서비스_3권역별 지가변동률속성조회 오퍼레이션 명세.csv
# 308_공간융합정보-3지가변동률정보서비스_3권역별 지가변동률속성조회 오퍼레이션 명세참고문서 Error
# HTTP Error 420: 420
# http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getByZoning?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/FluctuationRateofLandPriceService/attr/getByZoning?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보-3지가변동률정보서비스_5용도지역별지가변동률속성조회 오퍼레이션 명세/308_공간융합정보-3지가변동률정보서비스_5용도지역별지가변동률속성조회 오퍼레이션 명세.csv
# 308_공간융합정보-3지가변동률정보서비스_5용도지역별지가변동률속성조회 오퍼레이션 명세참고문서 Error
# HTTP Error 420: 420
# http://apis.data.go.kr/1611000/nsdi/BuildingUseService/wfs/getBuildingUseWFS?ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/BuildingUseService/wfs/getBuildingUseWFS?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보_4용도별건물정보서비스_2용도별건물WFS조회 오퍼레이션 명세/308_공간융합정보_4용도별건물정보서비스_2용도별건물WFS조회 오퍼레이션 명세.csv
# 100% [......................................................] 1488439 / 1488439http://apis.data.go.kr/1611000/nsdi/BuildingUseService/attr/getBuildingUse?pnu=1111017400&ServiceKey=
# fullUrl is http://apis.data.go.kr/1611000/nsdi/BuildingUseService/attr/getBuildingUse?pnu=1111017400&ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D
# ../../data/outbound/308_공간융합정보_4용도별건물정보서비스_3용도별건물속성조회 오퍼레이션 명세/308_공간융합정보_4용도별건물정보서비스_3용도별건물속성조회 오퍼레이션 명세.csv
# 308_공간융합정보_4용도별건물정보서비스_3용도별건물속성조회 오퍼레이션 명세참고문서 Error
# HTTP Error 420: 420
