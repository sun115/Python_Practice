# %%
import numpy as np
import pandas as pd 
import math

# %%
from sklearn import datasets, tree
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
featuresData = pd.read_csv("../dataset./feature_regression_example.csv")

# %%
featuresData.dtypes
# Out:
# REGIONID         object
# PRODUCTGROUP     object
# PRODUCT          object
# ITEM             object
# YEARWEEK          int64
# YEAR              int64
# WEEK              int64
# QTY               int64
# HOLIDAY          object
# HCLUS             int64
# PROMOTION        object
# PRO_PERCENT     float64
# dtype: object

# %%
featuresData["HD_YN"] = np.where(featuresData["HOLIDAY"] == "Y", 1, np.where(featuresData["HOLIDAY"]=="N",0,featuresData["HOLIDAY"]))
featuresData["PM_YN"] = np.where(featuresData["PROMOTION"] == "Y", 1, 0)

# %%
featuresData.head()
# Out:
#          REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201501  2015     1
# 1  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201502  2015     2
# 2  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201503  2015     3
# 3  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201504  2015     4
# 4  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201505  2015     5
#
#     QTY HOLIDAY  HCLUS PROMOTION  PRO_PERCENT HD_YN  PM_YN
# 0  1225       Y      1         Y     0.209442     1      1
# 1   968       N      4         Y     0.209442     0      1
# 2  1209       N      4         Y     0.208155     0      1
# 3  1810       Y      2         Y     0.208155     1      1
# 4  1773       N      4         Y     0.208155     0      1

# %%
featuresData2 = featuresData[(featuresData.YEARWEEK.astype(int)>=201501) & (featuresData.YEARWEEK.astype(int)<=201652)]

# %% [markdown]
# ## 01 상관관계 확인

# %%
corrDf = featuresData2.corr()
corrDf
# Out:
#              YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT  \
# YEARWEEK     1.000000  0.956598  0.275593  0.112267 -0.071586     0.404889
# YEAR         0.956598  1.000000 -0.016493  0.028931  0.028593     0.321193
# WEEK         0.275593 -0.016493  1.000000  0.289766 -0.339943     0.329705
# QTY          0.112267  0.028931  0.289766  1.000000 -0.537230     0.700195
# HCLUS       -0.071586  0.028593 -0.339943 -0.537230  1.000000    -0.545619
# PRO_PERCENT  0.404889  0.321193  0.329705  0.700195 -0.545619     1.000000
# PM_YN        0.205916  0.195931  0.060206  0.612451 -0.374072     0.898554
#
#                 PM_YN
# YEARWEEK     0.205916
# YEAR         0.195931
# WEEK         0.060206
# QTY          0.612451
# HCLUS       -0.374072
# PRO_PERCENT  0.898554
# PM_YN        1.000000

# %%
# 인덱스컬럼 초기화
corrResult = corrDf.reset_index()
corrResult
# Out:
#          index  YEARWEEK      YEAR      WEEK       QTY     HCLUS  PRO_PERCENT  \
# 0     YEARWEEK  1.000000  0.956598  0.275593  0.112267 -0.071586     0.404889
# 1         YEAR  0.956598  1.000000 -0.016493  0.028931  0.028593     0.321193
# 2         WEEK  0.275593 -0.016493  1.000000  0.289766 -0.339943     0.329705
# 3          QTY  0.112267  0.028931  0.289766  1.000000 -0.537230     0.700195
# 4        HCLUS -0.071586  0.028593 -0.339943 -0.537230  1.000000    -0.545619
# 5  PRO_PERCENT  0.404889  0.321193  0.329705  0.700195 -0.545619     1.000000
# 6        PM_YN  0.205916  0.195931  0.060206  0.612451 -0.374072     0.898554
#
#       PM_YN
# 0  0.205916
# 1  0.195931
# 2  0.060206
# 3  0.612451
# 4 -0.374072
# 5  0.898554
# 6  1.000000

# %%
# 상관관계 계수 비율 선정
featuresStd = 0.5

# feature 선택
features = corrResult[(corrResult.QTY != 1)\
                      &(abs(corrResult.QTY)>featuresStd)]["index"].tolist()
features
# Out:
# ['HCLUS', 'PRO_PERCENT', 'PM_YN']

# %%
label = ["QTY"]
label
# Out:
# ['QTY']

# %% [markdown]
# ## 02 특성 선정

# %%
yearweekStd = 201630

# %%
# 학습하려면 1,2번 사용이 적합

trainingData_features = featuresData2[featuresData2.YEARWEEK <= yearweekStd][features]
trainingData_label = featuresData2[featuresData2.YEARWEEK <= yearweekStd][label]
testData_features = featuresData2[featuresData2.YEARWEEK > yearweekStd][features]
testData_label = featuresData2[featuresData2.YEARWEEK > yearweekStd]

# %%
testData_label = testData_label.reset_index(drop=True)
testData_label
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# ...

# %%
### 디시전트리
# Define Model
model_method = tree.DecisionTreeRegressor()

# Learning (학습지표 & 결과값)
model = model_method.fit(trainingData_features,trainingData_label)

model
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
# Define Model
model_method2 = LinearRegression()

# Learning (학습지표 & 결과값)
model2 = model_method2.fit(trainingData_features,trainingData_label)

model2
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# 예측
predict = model.predict(testData_features)
predict
# Out:
# array([1606.5       , 1606.5       ,  350.71428571, 1434.6       ,
#        1434.6       , 1434.6       , 1434.6       , 1434.6       ,
#        1606.5       , 1606.5       , 2620.42857143, 1606.5       ,
#         350.71428571, 2193.8       , 2193.8       , 2193.8       ,
#        2193.8       , 2193.8       , 1434.6       , 1434.6       ,
#        1434.6       , 1434.6       ])

# %%
predict2 = model2.predict(testData_features)
predict2
# Out:
# array([[1375.69926506],
#        [1375.69926506],
#        [ 303.991336  ],
#        [1967.37842513],
#        [1967.37842513],
#        [1967.37842513],
#        [1532.2588619 ],
#        [1532.2588619 ],
#        [1375.69926506],
#        [1375.69926506],
#        [1665.77897389],
#        [1375.69926506],
#        [ 303.991336  ],
#        [2738.65667242],
#        [2738.65667242],
#        [2738.65667242],
#        [2738.65667242],
#        [2738.65667242],
#        [2158.49725478],
#        [1774.21460448],
#        [1774.21460448],
#        [2209.33416771]])

# %%
predictData = pd.DataFrame(predict, columns=["PREDICT"])

predictData
# Out:
#         PREDICT
# 0   1606.500000
# 1   1606.500000
# 2    350.714286
# 3   1434.600000
# 4   1434.600000
# 5   1434.600000
# 6   1434.600000
# 7   1434.600000
# 8   1606.500000
# 9   1606.500000
# 10  2620.428571
# 11  1606.500000
# 12   350.714286
# 13  2193.800000
# 14  2193.800000
# 15  2193.800000
# 16  2193.800000
# 17  2193.800000
# 18  1434.600000
# 19  1434.600000
# 20  1434.600000
# 21  1434.600000

# %%
predictData2 = pd.DataFrame(predict2, columns=["PREDICT2"])

predictData2
# Out:
#        PREDICT2
# 0   1375.699265
# 1   1375.699265
# 2    303.991336
# 3   1967.378425
# 4   1967.378425
# 5   1967.378425
# 6   1532.258862
# 7   1532.258862
# 8   1375.699265
# 9   1375.699265
# 10  1665.778974
# 11  1375.699265
# 12   303.991336
# 13  2738.656672
# 14  2738.656672
# 15  2738.656672
# 16  2738.656672
# 17  2738.656672
# 18  2158.497255
# 19  1774.214604
# 20  1774.214604
# 21  2209.334168

# %%
testData = pd.concat([testData_label, predictData, predictData2], axis=1)

# %%
testData
# Out:
#           REGIONID PRODUCTGROUP      PRODUCT      ITEM  YEARWEEK  YEAR  WEEK  \
# 0   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201631  2016    31
# 1   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201632  2016    32
# 2   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201633  2016    33
# 3   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201634  2016    34
# 4   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201635  2016    35
# 5   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201636  2016    36
# 6   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201637  2016    37
# 7   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201638  2016    38
# 8   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201639  2016    39
# 9   SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201640  2016    40
# 10  SEOUL_BANK_001         PG02  PRODUCT0010  ITEM0115    201641  2016    41
# ...

# %% [markdown]
# ## 03 모델 적용

# %%
### MAE
# 실제값과 예측값의 평균오차
mean_absolute_error(testData['QTY'], testData['PREDICT'])

### RMSE (MSE)
# 예측값 오차를 제곱 -> 평균 -> 루트
# 예측값 에러 잡기.
# MAE와 RMSE값 차이가 심하면, 안정적 모델이 아님. 쓸모없는 모델. useless
mean_squared_error(testData['QTY'], testData['PREDICT'])

### R2
r2_score(testData['QTY'], testData['PREDICT'])
# Out:
# 0.5144917252719985

# %%
mean_absolute_error(testData['QTY'], testData['PREDICT'])
# Out:
# 402.7435064935065

# %%
math.sqrt(mean_squared_error(testData['QTY'], testData['PREDICT']))
# Out:
# 476.11553668877247

# %%
r2_score(testData['QTY'], testData['PREDICT'])
# Out:
# 0.5144917252719985

# %%
mean_absolute_error(testData['QTY'], testData['PREDICT2'])
# Out:
# 558.0670525726194

# %%
math.sqrt(mean_squared_error(testData['QTY'], testData['PREDICT2']))
# Out:
# 713.5569550837886

# %%
r2_score(testData['QTY'], testData['PREDICT2'])
# Out:
# -0.09050890413294899

# %% [markdown]
# ## 결과 검증 (정확도 측정)

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %%
# dot_data = StringIO()
# export_graphviz(model, out_file=dot_data, 
#                 rounded=True,
#                 special_characters=True)
# graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
# Image(graph.create_png())

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x = testData["YEARWEEK"]
y = testData["QTY"]         # 여러개의 선을 그릴 수 있다. 
y2 = testData["PREDICT"]         # for문 역전시켜서 list에 적용가능.(ONLY 파이썬)
y3 = testData["PREDICT2"]

# %%
fig = plt.figure(figsize=(20,5))  
plt.plot(x,y,"yo-", label="QTY")
plt.plot(x,y2,"mo-", label="tree")
plt.plot(x,y3,"bo-", label="linear")
plt.grid(True)
plt.legend(loc=0)
