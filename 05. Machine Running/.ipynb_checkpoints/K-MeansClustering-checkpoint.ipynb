# %%
import pandas as pd
# K-Means 라이브러리
from sklearn.cluster import KMeans
# 시각화 라이브러리
import matplotlib.pyplot as plt

# %%
# Only needed if you want to display your plots inline if using Notebook
# change inline to auto if you have Spyder installed
# %matplotlib inline

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
#CSV 파일을 읽어 DataFrame 변수에 저장하기
studentData = pd.read_csv("../dataset/student_middle.csv")
studentData.head()
# Out:
#      NAME  SW  DB  AND
# 0  ST0001  95  30    0
# 1  ST0002  50  50    0
# 2  ST0003  15  30   15
# 3  ST0004  90  50   20
# 4  ST0005  75  20   20

# %% [markdown]
# ### 2. 데이터 분리

# %%
### 기본정보 가지고 있기
name = studentData[["NAME"]]
### 특성정보 분리
features = studentData[["SW","DB","AND"]]

# %% [markdown]
# ### 3. 모델선언 및 자율학습 예측

# %%
model = KMeans(n_clusters=5, algorithm="auto")
model.fit(features)
### ATL (Above The Line) 가시적, 
### BTL (Below The Line) 비가시적, 신문광고 등
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# ### 4. 데이터 정리

# %%
predict = pd.DataFrame(model.predict(features))
predict.columns=["PREDICT"]

# %%
### name, feature, predict 붙이기
result = pd.concat([name, features, predict], axis = 1)
result
# Out:
#       NAME   SW   DB  AND  PREDICT
# 0   ST0001   95   30    0        4
# 1   ST0002   50   50    0        4
# 2   ST0003   15   30   15        3
# 3   ST0004   90   50   20        4
# 4   ST0005   75   20   20        4
# 5   ST0006  100   80   30        1
# 6   ST0007   15   10   30        3
# 7   ST0008  100  100   33        1
# 8   ST0009   65   60   35        0
# 9   ST0010   90   20   38        0
# 10  ST0011  100   70   43        1
# 11  ST0012   90   45   45        0
# 12  ST0013   90   60   47        0
# 13  ST0014  100  100   48        1
# 14  ST0015   75   80   49        1
# 15  ST0016   90  100   50        1
# 16  ST0017  100   30   50        0
# 17  ST0018  100  100   58        1
# 18  ST0019  100  100   60        1
# 19  ST0020   90   80   69        1
# 20  ST0021  100  100   75        2
# 21  ST0022  100  100   95        2
# 22  ST0023  100  100   96        2
# 23  ST0024  100  100  100        2
# 24  ST0025   90  100  100        2
# 25  ST0026  100  100  100        2

# %% [markdown]
# ### 5. 시각화

# %%
### 시각화 하기
plt.scatter(result['DB'],result["AND"], c=result["PREDICT"], alpha=0.7)

# %%
customerData = pd.read_csv("../dataset/customerdata.csv")
customerData.head(20)
# Out:
#     CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0   A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1   A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2   A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3   A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4   B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5   B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6   B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7   C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8   C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9   C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10  C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11  C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
kopoData = pd.read_csv("../dataset/kopo_customerdata.csv")
kopoData.head()
# Out:
#    CUSTOMERCODE STATENAME  ST  GENDER  DOB  GENDER1  EMAIL  FEST_CNT  \
# 0       1503989    State2   2    Male    0        1      1         0
# 1       1190338    State2   2    Male    0        1      0         1
# 2       1424715    State2   2  Female    0        2      0         0
# 3       2483305    State2   2    Male    0        1      0         1
# 4       1178802    State2   2    Male    0        1      0         1
#
#    TOTAL_AMOUNT  AC_AMOUNT  AV_AMOUNT  HA_AMOUNT  EMI_CE_AMOUNT  IS_HIGHEND  \
# 0         30300          0      30300          0              0           0
# 1         46500          0      46500          0              0           0
# 2         22700          0          0      22700              0           0
# 3         31400          0      31400          0              0           0
# 4         44900          0          0      44900              0           0
#
#    CNT_VIST  GAP_VISIT
# 0         1          0
# 1         1          0
# ...

# %%
custId = customerData[["CUSTID"]]
features = customerData[["AVERAGEPRICE","EMI","DEVICECOUNT","PRODUCTAGE"]]
custtype = customerData[["CUSTTYPE"]]

# %%
model = KMeans(n_clusters=3, algorithm="auto")
model.fit(features)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
predict = pd.DataFrame(model.predict(features))
predict.columns=["PREDICT"]

# %%
result = pd.concat([custId, features, custtype, predict], axis = 1)
result
# Out:
#      CUSTID  AVERAGEPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE  \
# 0    A13566   4273.900000    3          6.4    1.679181  Big-Screen-lover
# 1    A14219   3642.441950    2          4.0    2.682023      Sleeping-dog
# 2    A15312   3653.884565    2          5.0    3.208202      Sleeping-dog
# 3    A16605   3713.211107    2          6.6    0.900000        Early-bird
# 4    B10634   3391.074215    2          4.2    2.453656      Sleeping-dog
# 5    B16849   3755.263391    2          4.7    2.786665      Sleeping-dog
# 6    B18816   3213.911446    2          6.4    0.900000        Early-bird
# 7    C10639   3516.500000    2          5.2    2.564830  Big-Screen-lover
# 8    C12717   3732.900000    2          5.7    2.069995  Big-Screen-lover
# 9    C15050   4020.173425    2          4.9    3.013440      Sleeping-dog
# 10   C18306   4005.005142    2          4.7    3.113618      Sleeping-dog
# 11   C18622   3246.000000    1          5.0    1.891624  Big-Screen-lover
# ...

# %%
plt.scatter(result['AVERAGEPRICE'],result["PRODUCTAGE"], c=result["PREDICT"], alpha=0.7)

# %%
import seaborn as sns
