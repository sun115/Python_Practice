# %%
import requests #Used to service API connection
from lxml import html #Used to parse XML
from bs4 import BeautifulSoup #Used to read XML table on webpage
import pandas as pd
import numpy as np
import wget

# %% [markdown]
# # 공간융합정보 - 용도별건물정보서비스

# %%
def atypical_xml_process(url, itemList, separatorTag):
    response = requests.get(url)
    if response.status_code == 200:
        Data = BeautifulSoup(response.text, 'lxml-xml')
        tempDict = {}
        for i in itemList:
            tempDict[i] = []
        iterData = Data.find_all(separatorTag)
        for i in range(0, len(iterData)):
            for j in range(0, len(itemList)):
                eachData = iterData[i].find_all(itemList[j])
                eachItemList = []
                if eachData == []:
                    eachItemList.append('')
                else:
                    for k in range(0, len(eachData)):
                        tag = eachData[k]
                        eachItemList.append(tag.text)
                tempDict[itemList[j]] += eachItemList
        finalResult = pd.DataFrame(tempDict, columns=itemList)
    return finalResult

# %%
url = 'http://apis.data.go.kr/1611000/nsdi/BuildingUseService/wfs/getBuildingUseWFS?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D&maxfeatures=10&typename=F253&bbox=217694,448235,218608,449094,EPSG:5174&pnu=414501080010325&maxFeatures=10&resultType=results&srsName=EPSG:5174'
itemList = ['SHAPE', 'GIS_IDNTFC_NO', 'PNU', 'LD_CPSG_CODE', 'LD_EMD_LI_CODE', 'REGSTR_SE_CODE', 'MNNM', 'SLNO', 'SRC_OBJECTID', 'SRC_LD_CPSG_CODE', 'BULD_IDNTFC_NO', 'AGBLDG_SE_CODE', 'BULD_KND_CODE', 'BULD_NM', 'BULD_DONG_NM', 'BULD_MAIN_ATACH_SE_CODE', 'BULD_PLOT_AR', 'BULD_BILDNG_AR', 'BULD_TOTAR', 'MEASRMT_RT', 'BTL_RT', 'STRCT_CODE', 'STRCT_CODE_NM', 'MAIN_PRPOS_CODE', 'MAIN_PRPOS_CODE_NM', 'DETAIL_PRPOS_CODE', 'DETAIL_PRPOS_CODE_NM', 'BULD_PRPOS_CL_CODE', 'BULD_PRPOS_CL_CODE_NM', 'BULD_HG', 'GROUND_FLOOR_CO', 'UNDGRND_FLOOR_CO', 'PRMISN_DE', 'USE_CONFM_DE', 'FRST_REGIST_DT']
separatorTag = 'gml:featureMember'

# %%
url ='http://apis.data.go.kr/1611000/nsdi/BuildingUseService/attr/getBuildingUse?ServiceKey=aDTqxJKNQ6XA6akRhrCF1ZSGXu8uk6HwyjXEWNetiKZEo%2FAD1M38g97KxPIXwL5k4RBnx%2BJwa6DzpTgn0G6AEg%3D%3D&pnu=1111017400&mainPrposCode=02000&detailPrposCode=02001&format=xml&numOfRows=10&pageNo=1'
itemList =['gisIdntfcNo','pnu','ldCode','ldCodeNm','regstrSeCode','regstrSeCodeNm','mnnmSlno','buldIdntfcNo','agbldgSeCode','agbldgSeCodeNm','buldKndCode','buldKndCodeNm','buldNm','buldDongNm','buldMainAtachSeCode','buldMainAtachSeCodeNm','buldPlotAr','buldBildngAr','buldTotar','measrmtRt','btlRt','strctCode','strctCodeNm','mainPrposCode','mainPrposCodeNm','detailPrposCode','detailPrposCodeNm','buldPrposClCode','buldPrposClCodeNm','buldHg','groundFloorCo','undgrndFloorCo','prmisnDe','useConfmDe','lastUpdtDt']
separatorTag = 'field'

# %%
atypical_xml_process(url, itemList, separatorTag)
# Out:
#                     gisIdntfcNo                  pnu      ldCode  \
# 0  2006201260634527866900000000  1111017400100230076  1111017400
# 1  2002200875294530040400000000  1111017400100230326  1111017400
# 2  2003201260124528406700000000  1111017400100230816  1111017400
# 3  1999201208764524625400000000  1111017400102320000  1111017400
# 4  1999201196904524043000000000  1111017400102320000  1111017400
# 5  1999201153764524208700000000  1111017400102320000  1111017400
# 6  0000200903904522337000000000  1111017400105780005  1111017400
# 7  2002200815114528749900000000  1111017400106010000  1111017400
# 8  2002200796004528528500000000  1111017400106010001  1111017400
# 9  2002200815034528507000000000  1111017400106010002  1111017400
#
#         ldCodeNm regstrSeCode regstrSeCodeNm mnnmSlno buldIdntfcNo  \
# 0  서울특별시 종로구 창신동            1             일반    23-76         5072
# 1  서울특별시 종로구 창신동            1             일반   23-326         7319
# 2  서울특별시 종로구 창신동            1             일반   23-816        10460
# 3  서울특별시 종로구 창신동            1             일반      232         1888
# 4  서울특별시 종로구 창신동            1             일반      232         1889
# 5  서울특별시 종로구 창신동            1             일반      232         1890
# 6  서울특별시 종로구 창신동            1             일반    578-5        13134
# 7  서울특별시 종로구 창신동            1             일반      601        17908
# 8  서울특별시 종로구 창신동            1             일반    601-1        20277
# 9  서울특별시 종로구 창신동            1             일반    601-2        27811
#
#   agbldgSeCode agbldgSeCodeNm     ...     detailPrposCode detailPrposCodeNm  \
# 0            2          집합건축물     ...               02001               아파트
# 1            2          집합건축물     ...               02001               아파트
# 2            2          집합건축물     ...               02001               아파트
# 3            2          집합건축물     ...               02001               아파트
# 4            2          집합건축물     ...               02001               아파트
# 5            2          집합건축물     ...               02001               아파트
# 6            2          집합건축물     ...               02001               아파트
# 7            2          집합건축물     ...               02001               아파트
# 8            2          집합건축물     ...               02001               아파트
# 9            2          집합건축물     ...               02001               아파트
#
#   buldPrposClCode buldPrposClCodeNm buldHg groundFloorCo undgrndFloorCo  \
# 0               1               주거용  47.88            15              3
# 1               1               주거용     23             6              2
# 2               1               주거용   51.2            19              2
# 3               1               주거용   62.4            23              2
# 4               1               주거용   48.4            18              2
# 5               1               주거용   62.4            23              1
# 6               1               주거용      0            10              1
# 7               1               주거용  23.93             8              1
# 8               1               주거용   21.1             7              1
# 9               1               주거용  23.79             8              1
#
#      prmisnDe  useConfmDe  lastUpdtDt
# 0  2003-05-09  2006-09-04  2019-01-02
# 1  2000-05-22  2002-05-31  2019-01-02
# 2  2000-07-13  2003-08-08  2019-01-02
# 3  1996-07-11  1999-04-30  2019-01-02
# 4  1996-07-11  1999-04-30  2019-01-02
# 5  1996-07-11  1999-04-30  2019-01-02
# 6              1973-01-25  2019-01-02
# 7  1997-08-13  2002-12-30  2019-01-02
# 8  1997-08-13  2002-12-30  2019-01-02
# 9  1997-09-26  2002-12-30  2019-01-02
#
# [10 rows x 35 columns]
